# %%
import pandas as pd

# %%
movies=pd.read_csv(r'C:\mini_proj\Movies_Rec\Top Indian Movies.csv')

# %%
movies.head(10)
# Out:
#                         Title  Year of Release  Rating Number of Reviews  \
# 0                  Anbe Sivam             2003     8.7               21K
# 1                     Golmaal             1979     8.5               19K
# 2                    Jai Bhim             2021     8.9              193K
# 3                     Nayakan             1987     8.6               20K
# 4           Pariyerum Perumal             2018     8.7               16K
# 5  Rocketry: The Nambi Effect             2022     9.2               18K
# 6                    3 Idiots             2009     8.4              391K
# 7                 Apur Sansar             1959     8.5               15K
# 8            Manichitrathazhu             1993     8.7               11K
# 9           Kumbalangi Nights             2019     8.5               15K
#
#   Popularity Index                                         Movie Cast  \
# 0           11,629  ['Kamal Haasan', 'Madhavan', 'Kiran Rathod', '...
# ...

# %%
movies.describe()
# Out:
#        Year of Release      Rating
# count       250.000000  250.000000
# mean       2008.068000    8.161200
# std          14.198796    0.270754
# min        1955.000000    7.700000
# 25%        2004.000000    8.000000
# 50%        2013.000000    8.100000
# 75%        2018.000000    8.300000
# max        2022.000000    9.200000

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Title              250 non-null    object
#  1   Year of Release    250 non-null    int64
#  2   Rating             250 non-null    float64
#  3   Number of Reviews  250 non-null    object
#  4   Popularity Index   250 non-null    object
#  5   Movie Cast         250 non-null    object
#  6   Director           250 non-null    object
#  7   Description        250 non-null    object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 15.8+ KB

# %%
movies.isnull().sum()
# Out:
# Title                0
# Year of Release      0
# Rating               0
# Number of Reviews    0
# Popularity Index     0
# Movie Cast           0
# Director             0
# Description          0
# dtype: int64

# %% [markdown]
# Feature Selection Part

# %%
movies.columns
# Out:
# Index(['Title', 'Year of Release', 'Rating', 'Number of Reviews',
#        'Popularity Index', 'Movie Cast', 'Director', 'Description'],
#       dtype='object')

# %%
movies=movies[['Title', 'Movie Cast', 'Director','Description']]

# %%
movies
# Out:
#                     Title                                         Movie Cast  \
# 0              Anbe Sivam  ['Kamal Haasan', 'Madhavan', 'Kiran Rathod', '...
# 1                 Golmaal  ['Amol Palekar', 'Bindiya Goswami', 'Deven Ver...
# 2                Jai Bhim  ['Suriya', 'Lijo Mol Jose', 'Manikandan K.', '...
# 3                 Nayakan  ['Kamal Haasan', 'Saranya Ponvannan', 'Delhi G...
# 4       Pariyerum Perumal  ['Kathir', 'Anandhi', 'Yogi Babu', 'Lijeesh', ...
# ..                    ...                                                ...
# 245                    24  ['Suriya', 'Samantha Ruth Prabhu', 'Nithya Men...
# 246       Kapoor and Sons  ['Rishi Kapoor', 'Rajat Kapoor', 'Ratna Pathak...
# 247  Velaiilla Pattadhari  ['Dhanush', 'Saranya Ponvannan', 'Amala Paul',...
# 248          Colour Photo  ['Suhas', 'Chandini Chowdary', 'Sunil', 'Harsh...
# 249              Rockstar  ['Ranbir Kapoor', 'Nargis Fakhri', 'Shammi Kap...
#
# ...

# %%
movies = movies.copy()
movies['tags'] = movies['Description'] + movies['Movie Cast']

# %%
movies
# Out:
#                     Title                                         Movie Cast  \
# 0              Anbe Sivam  ['Kamal Haasan', 'Madhavan', 'Kiran Rathod', '...
# 1                 Golmaal  ['Amol Palekar', 'Bindiya Goswami', 'Deven Ver...
# 2                Jai Bhim  ['Suriya', 'Lijo Mol Jose', 'Manikandan K.', '...
# 3                 Nayakan  ['Kamal Haasan', 'Saranya Ponvannan', 'Delhi G...
# 4       Pariyerum Perumal  ['Kathir', 'Anandhi', 'Yogi Babu', 'Lijeesh', ...
# ..                    ...                                                ...
# 245                    24  ['Suriya', 'Samantha Ruth Prabhu', 'Nithya Men...
# 246       Kapoor and Sons  ['Rishi Kapoor', 'Rajat Kapoor', 'Ratna Pathak...
# 247  Velaiilla Pattadhari  ['Dhanush', 'Saranya Ponvannan', 'Amala Paul',...
# 248          Colour Photo  ['Suhas', 'Chandini Chowdary', 'Sunil', 'Harsh...
# 249              Rockstar  ['Ranbir Kapoor', 'Nargis Fakhri', 'Shammi Kap...
#
# ...

# %%
new_data  = movies.drop(columns=['Description'])

# %%
new_data
# Out:
#                     Title                                         Movie Cast  \
# 0              Anbe Sivam  ['Kamal Haasan', 'Madhavan', 'Kiran Rathod', '...
# 1                 Golmaal  ['Amol Palekar', 'Bindiya Goswami', 'Deven Ver...
# 2                Jai Bhim  ['Suriya', 'Lijo Mol Jose', 'Manikandan K.', '...
# 3                 Nayakan  ['Kamal Haasan', 'Saranya Ponvannan', 'Delhi G...
# 4       Pariyerum Perumal  ['Kathir', 'Anandhi', 'Yogi Babu', 'Lijeesh', ...
# ..                    ...                                                ...
# 245                    24  ['Suriya', 'Samantha Ruth Prabhu', 'Nithya Men...
# 246       Kapoor and Sons  ['Rishi Kapoor', 'Rajat Kapoor', 'Ratna Pathak...
# 247  Velaiilla Pattadhari  ['Dhanush', 'Saranya Ponvannan', 'Amala Paul',...
# 248          Colour Photo  ['Suhas', 'Chandini Chowdary', 'Sunil', 'Harsh...
# 249              Rockstar  ['Ranbir Kapoor', 'Nargis Fakhri', 'Shammi Kap...
#
# ...

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
cv=CountVectorizer(max_features=10000, stop_words='english')

# %%
cv
# Out:
# CountVectorizer(max_features=10000, stop_words='english')

# %%
vector=cv.fit_transform(new_data['tags'].values.astype('U')).toarray()

# %%
vector.shape
# Out:
# (250, 5125)

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
similarity=cosine_similarity(vector)

# %%
similarity
# Out:
# array([[1.        , 0.        , 0.02441931, ..., 0.05847053, 0.        ,
#         0.        ],
#        [0.        , 1.        , 0.02299002, ..., 0.05504819, 0.        ,
#         0.02051525],
#        [0.02441931, 0.02299002, 1.        , ..., 0.0556846 , 0.02473853,
#         0.02075243],
#        ...,
#        [0.05847053, 0.05504819, 0.0556846 , ..., 1.        , 0.        ,
#         0.        ],
#        [0.        , 0.        , 0.02473853, ..., 0.        , 1.        ,
#         0.04415108],
#        [0.        , 0.02051525, 0.02075243, ..., 0.        , 0.04415108,
#         1.        ]])

# %%
new_data[new_data['title']=="The Godfather"].index[0]
# Out:
# 2

# %%
distance = sorted(list(enumerate(similarity[2])), reverse=True, key=lambda vector:vector[1])
for i in distance[0:5]:
    print(new_data.iloc[i[0]].Title)
# Out:
# Jai Bhim
# Bommarillu
# Soodhu Kavvum
# Dhuruvangal Pathinaaru
# Athadu

# %%
def recommand(movies):
    index=new_data[new_data['Title']==movies].index[0]
    distance = sorted(list(enumerate(similarity[index])), reverse=True, key=lambda vector:vector[1])
    for i in distance[0:5]:
        print(new_data.iloc[i[0]].Title)

# %%
recommand("Vikram")
# Out:
# Vikram
# Unnaipol Oruvan
# 96
# Super Deluxe
# Jai Bhim

# %%
import pickle

# %%
pickle.dump(new_data, open('C:\mini_proj\Movies_Rec\movies_list.pkl', 'wb'))

# %%
pickle.dump(similarity, open('C:\mini_proj\Movies_Rec\similarity.pkl', 'wb'))

# %%
pickle.load(open('C:\mini_proj\Movies_Rec\movies_list.pkl', 'rb'))
# Out:
#                     Title                                         Movie Cast  \
# 0              Anbe Sivam  ['Kamal Haasan', 'Madhavan', 'Kiran Rathod', '...
# 1                 Golmaal  ['Amol Palekar', 'Bindiya Goswami', 'Deven Ver...
# 2                Jai Bhim  ['Suriya', 'Lijo Mol Jose', 'Manikandan K.', '...
# 3                 Nayakan  ['Kamal Haasan', 'Saranya Ponvannan', 'Delhi G...
# 4       Pariyerum Perumal  ['Kathir', 'Anandhi', 'Yogi Babu', 'Lijeesh', ...
# ..                    ...                                                ...
# 245                    24  ['Suriya', 'Samantha Ruth Prabhu', 'Nithya Men...
# 246       Kapoor and Sons  ['Rishi Kapoor', 'Rajat Kapoor', 'Ratna Pathak...
# 247  Velaiilla Pattadhari  ['Dhanush', 'Saranya Ponvannan', 'Amala Paul',...
# 248          Colour Photo  ['Suhas', 'Chandini Chowdary', 'Sunil', 'Harsh...
# 249              Rockstar  ['Ranbir Kapoor', 'Nargis Fakhri', 'Shammi Kap...
#
# ...
